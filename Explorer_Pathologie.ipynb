# %%
import pandas as pd

df = pd.read_csv(
    'Donnees/sante/donnees_utils/pathologie_effectifs_en_fnct_des_régions.csv', 
    sep=';',  
    engine='python' 
)

# %%
df = pd.read_csv(
    'Donnees/sante/donnees_utils/pathologie_effectifs_en_fnct_des_régions.csv'
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2748226 entries, 0 to 2748225
# Data columns (total 17 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Unnamed: 0              int64
#  1   annee                   int64
#  2   patho_niv1              object
#  3   patho_niv2              object
#  4   patho_niv3              object
#  5   top                     object
#  6   cla_age_5               object
#  7   sexe                    int64
#  8   region                  int64
#  9   dept                    int64
#  10  Ntop                    float64
#  11  Npop                    int64
#  12  prev                    float64
#  13  libelle_classe_age      object
#  14  libelle_sexe            object
#  15  tri                     float64
#  16  Niveau_prioritaire_num  int64
# dtypes: float64(3), int64(7), object(7)
# memory usage: 356.4+ MB

# %%
df['patho_niv1'].unique()
# Out:
# array(['Maladies inflammatoires ou rares ou infection VIH',
#        'Maladies neurologiques', 'Maladies psychiatriques',
#        'Pas de pathologie repérée, traitement, maternité, hospitalisation ou traitement antalgique ou anti-inflammatoire',
#        'Traitements du risque vasculaire (hors pathologies)',
#        'Traitements psychotropes (hors pathologies)',
#        'Maladies cardioneurovasculaires',
#        'Maladies respiratoires chroniques (hors mucoviscidose)',
#        'Traitements antalgiques ou anti-inflammatoires (hors pathologies, traitements, maternité ou hospitalisations)',
#        'Maladies du foie ou du pancréas (hors mucoviscidose)',
#        'Maternité (avec ou sans pathologies)',
#        'Insuffisance rénale chronique terminale',
#        'Hospitalisations hors pathologies repérées (avec ou sans pathologies, traitements ou maternité)',
#        'Cancers', 'Diabète',
#        "Affections de longue durée (dont 31 et 32) pour d'autres causes",
# ...

# %%
df['patho_niv2'].unique()
# Out:
# array(['Maladies rares', 'Autres affections neurologiques',
#        'Autres troubles psychiatriques', 'Déficience mentale',
#        'Pas de pathologie repérée, traitement, maternité, hospitalisation ou traitement antalgique ou anti-inflammatoire',
#        'Traitements antihypertenseurs (hors pathologies)',
#        'Traitements antidépresseurs ou thymorégulateurs (hors pathologies)',
#        'Traitements anxiolytiques (hors pathologies)',
#        'Infection par le VIH',
#        'Traitements hypolipémiants (hors pathologies)',
#        'Troubles addictifs', "Troubles névrotiques et de l'humeur",
#        "Troubles psychiatriques débutant dans l'enfance",
#        'Troubles psychotiques', 'Maladies inflammatoires chroniques',
#        'Maladie coronaire', 'Maladie valvulaire',
#        'Insuffisance cardiaque', 'Artériopathie périphérique',
#        'Autres affections cardiovasculaires',
#        "Démences (dont maladie d'Alzheimer)", 'Lésion médullaire',
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  annee                                         patho_niv1  \
# 0           0   2023  Maladies inflammatoires ou rares ou infection VIH
# 1           1   2023  Maladies inflammatoires ou rares ou infection VIH
# 2           2   2023  Maladies inflammatoires ou rares ou infection VIH
# 3           3   2023  Maladies inflammatoires ou rares ou infection VIH
# 4           4   2023  Maladies inflammatoires ou rares ou infection VIH
#
#        patho_niv2     patho_niv3          top cla_age_5  sexe  region  dept  \
# 0  Maladies rares  Mucoviscidose  RAR_MUC_IND     tsage     1      11    75
# 1  Maladies rares  Mucoviscidose  RAR_MUC_IND     tsage     1      24    28
# 2  Maladies rares  Mucoviscidose  RAR_MUC_IND     tsage     1      24   999
# 3  Maladies rares  Mucoviscidose  RAR_MUC_IND     tsage     1      27    39
# 4  Maladies rares  Mucoviscidose  RAR_MUC_IND     tsage     1      27    71
#
#     Ntop     Npop   prev libelle_classe_age libelle_sexe   tri  \
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0                0
# annee                     0
# patho_niv1                0
# patho_niv2                0
# patho_niv3                0
# top                       0
# cla_age_5                 0
# sexe                      0
# region                    0
# dept                      0
# Ntop                      0
# Npop                      0
# prev                      0
# libelle_classe_age        0
# libelle_sexe              0
# tri                       0
# Niveau_prioritaire_num    0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isna().sum()
# Out:
# Unnamed: 0                0
# annee                     0
# patho_niv1                0
# patho_niv2                0
# patho_niv3                0
# top                       0
# cla_age_5                 0
# sexe                      0
# region                    0
# dept                      0
# Ntop                      0
# Npop                      0
# prev                      0
# libelle_classe_age        0
# libelle_sexe              0
# tri                       0
# Niveau_prioritaire_num    0
# dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0  annee                                         patho_niv1  \
# 0           0   2023  Maladies inflammatoires ou rares ou infection VIH
# 1           1   2023  Maladies inflammatoires ou rares ou infection VIH
# 2           2   2023  Maladies inflammatoires ou rares ou infection VIH
# 3           3   2023  Maladies inflammatoires ou rares ou infection VIH
# 4           4   2023  Maladies inflammatoires ou rares ou infection VIH
#
#        patho_niv2     patho_niv3          top cla_age_5  sexe  region  dept  \
# 0  Maladies rares  Mucoviscidose  RAR_MUC_IND     tsage     1      11    75
# 1  Maladies rares  Mucoviscidose  RAR_MUC_IND     tsage     1      24    28
# 2  Maladies rares  Mucoviscidose  RAR_MUC_IND     tsage     1      24   999
# 3  Maladies rares  Mucoviscidose  RAR_MUC_IND     tsage     1      27    39
# 4  Maladies rares  Mucoviscidose  RAR_MUC_IND     tsage     1      27    71
#
#     Ntop     Npop   prev libelle_classe_age libelle_sexe   tri  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2748226 entries, 0 to 2748225
# Data columns (total 17 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Unnamed: 0              int64
#  1   annee                   int64
#  2   patho_niv1              object
#  3   patho_niv2              object
#  4   patho_niv3              object
#  5   top                     object
#  6   cla_age_5               object
#  7   sexe                    int64
#  8   region                  int64
#  9   dept                    int64
#  10  Ntop                    float64
#  11  Npop                    int64
#  12  prev                    float64
#  13  libelle_classe_age      object
#  14  libelle_sexe            object
#  15  tri                     float64
#  16  Niveau_prioritaire_num  int64
# dtypes: float64(3), int64(7), object(7)
# memory usage: 356.4+ MB

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df['dept'] = pd.to_numeric(df['dept'], errors='coerce')
df.dropna(subset=['dept'], inplace=True)
df['dept'] = df['dept'].astype(int)

# %%
df.head()
# Out:
#    annee                                         patho_niv1      patho_niv2  \
# 0   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 1   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 2   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 3   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 4   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
#
#       patho_niv3          top cla_age_5  sexe  region  dept   Ntop     Npop  \
# 0  Mucoviscidose  RAR_MUC_IND     tsage     1      11    75  150.0   981490
# 1  Mucoviscidose  RAR_MUC_IND     tsage     1      24    28   30.0   204050
# 2  Mucoviscidose  RAR_MUC_IND     tsage     1      24   999  170.0  1214070
# 3  Mucoviscidose  RAR_MUC_IND     tsage     1      27    39   20.0   123680
# 4  Mucoviscidose  RAR_MUC_IND     tsage     1      27    71   40.0   259740
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2748226 entries, 0 to 2748225
# Data columns (total 16 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   annee                   int64
#  1   patho_niv1              object
#  2   patho_niv2              object
#  3   patho_niv3              object
#  4   top                     object
#  5   cla_age_5               object
#  6   sexe                    int64
#  7   region                  int64
#  8   dept                    int32
#  9   Ntop                    float64
#  10  Npop                    int64
#  11  prev                    float64
#  12  libelle_classe_age      object
#  13  libelle_sexe            object
#  14  tri                     float64
#  15  Niveau_prioritaire_num  int64
# dtypes: float64(3), int32(1), int64(5), object(7)
# memory usage: 325.0+ MB

# %%
df.reset_index(drop=True, inplace=True)

# %%
def extraire_min_priorite(val):
    morceaux = str(val).split(',')
    return min(int(x) for x in morceaux)

df['Niveau_prioritaire_num'] = df['Niveau prioritaire'].apply(extraire_min_priorite)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\pc\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Niveau prioritaire'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 5
#       2     morceaux = str(val).split(',')
# ...

# %%
df.head()
# Out:
#    annee                                         patho_niv1      patho_niv2  \
# 0   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 1   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 2   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 3   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 4   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
#
#       patho_niv3          top cla_age_5  sexe  region  dept   Ntop     Npop  \
# 0  Mucoviscidose  RAR_MUC_IND     tsage     1      11    75  150.0   981490
# 1  Mucoviscidose  RAR_MUC_IND     tsage     1      24    28   30.0   204050
# 2  Mucoviscidose  RAR_MUC_IND     tsage     1      24   999  170.0  1214070
# 3  Mucoviscidose  RAR_MUC_IND     tsage     1      27    39   20.0   123680
# 4  Mucoviscidose  RAR_MUC_IND     tsage     1      27    71   40.0   259740
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2748226 entries, 0 to 2748225
# Data columns (total 16 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   annee                   int64
#  1   patho_niv1              object
#  2   patho_niv2              object
#  3   patho_niv3              object
#  4   top                     object
#  5   cla_age_5               object
#  6   sexe                    int64
#  7   region                  int64
#  8   dept                    int32
#  9   Ntop                    float64
#  10  Npop                    int64
#  11  prev                    float64
#  12  libelle_classe_age      object
#  13  libelle_sexe            object
#  14  tri                     float64
#  15  Niveau_prioritaire_num  int64
# dtypes: float64(3), int32(1), int64(5), object(7)
# memory usage: 325.0+ MB

# %%
df['Niveau_prioritaire_num'].unique()
# Out:
# array([3, 2, 1], dtype=int64)

# %%
df.isna().sum()
# Out:
# annee                     0
# patho_niv1                0
# patho_niv2                0
# patho_niv3                0
# top                       0
# cla_age_5                 0
# sexe                      0
# region                    0
# dept                      0
# Ntop                      0
# Npop                      0
# prev                      0
# libelle_classe_age        0
# libelle_sexe              0
# tri                       0
# Niveau_prioritaire_num    0
# dtype: int64

# %%
df.drop(columns=['Niveau prioritaire'], inplace=True)

# %%
# adapter a votre chemain  
df.to_csv('Donnees/sante/donnees_utils/pathologie_effectifs_en_fnct_des_régions.csv')

# %%
import pandas as pd
df=pd.read_csv(
    'Donnees/sante/donnees_utils/pathologie_effectifs_en_fnct_des_régions.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  annee                                         patho_niv1  \
# 0           0   2023  Maladies inflammatoires ou rares ou infection VIH
# 1           1   2023  Maladies inflammatoires ou rares ou infection VIH
# 2           2   2023  Maladies inflammatoires ou rares ou infection VIH
# 3           3   2023  Maladies inflammatoires ou rares ou infection VIH
# 4           4   2023  Maladies inflammatoires ou rares ou infection VIH
#
#        patho_niv2     patho_niv3          top cla_age_5  sexe  region  dept  \
# 0  Maladies rares  Mucoviscidose  RAR_MUC_IND     tsage     1      11    75
# 1  Maladies rares  Mucoviscidose  RAR_MUC_IND     tsage     1      24    28
# 2  Maladies rares  Mucoviscidose  RAR_MUC_IND     tsage     1      24   999
# 3  Maladies rares  Mucoviscidose  RAR_MUC_IND     tsage     1      27    39
# 4  Maladies rares  Mucoviscidose  RAR_MUC_IND     tsage     1      27    71
#
#     Ntop     Npop   prev libelle_classe_age libelle_sexe   tri  \
# ...

# %%
df['region'].unique()
# Out:
# array([11, 24, 27, 32, 44, 52, 53, 75, 76, 84, 93,  1,  4, 28,  2, 99,  3,
#        94,  6], dtype=int64)

# %%
code_region,nom_region
01,Guadeloupe
02,Martinique
03,Guyane
04,La Réunion
06,Mayotte
11,Île-de-France
24,Centre-Val de Loire
27,Bourgogne-Franche-Comté
28,Normandie
32,Hauts-de-France
44,Grand Est
52,Pays de la Loire
53,Bretagne
75,Nouvelle-Aquitaine
76,Occitanie
84,Auvergne-Rhône-Alpes
93,Provence-Alpes-Côte d'Azur
94,Corse
