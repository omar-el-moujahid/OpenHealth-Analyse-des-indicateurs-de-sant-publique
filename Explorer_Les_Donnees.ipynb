# %%
import pandas as pd
bd1=pd.read_csv('Donnees\covid-hosp-txad-age-fra-2023-06-30-16h29.csv')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\c'
# <>:2: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\pc\AppData\Local\Temp\ipykernel_28592\2428504142.py:2: SyntaxWarning: invalid escape sequence '\c'
#   bd1=pd.read_csv('Donnees\covid-hosp-txad-age-fra-2023-06-30-16h29.csv')

# %%
import requests

url = 'https://geo.api.gouv.fr/departements/01/communes'
# A GET request to the API
response = requests.get(url)

# Print the response
data = response.json()
print(data[0])
# Out:
# {'nom': "L'Abergement-Clémenciat", 'code': '01001', 'codeDepartement': '01', 'siren': '210100012', 'codeEpci': '200069193', 'codeRegion': '84', 'codesPostaux': ['01400'], 'population': 859}

# %%
import json 
df = pd.read_json(json.dumps(response.json()))
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_28592\1533993577.py:2: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(json.dumps(response.json()))

# %%
df
# Out:
#                          nom  code  codeDepartement      siren   codeEpci  \
# 0    L'Abergement-Clémenciat  1001                1  210100012  200069193
# 1      L'Abergement-de-Varey  1002                1  210100020  240100883
# 2          Ambérieu-en-Bugey  1004                1  210100046  240100883
# 3        Ambérieux-en-Dombes  1005                1  210100053  200042497
# 4                    Ambléon  1006                1  210100061  200040350
# ..                       ...   ...              ...        ...        ...
# 386          Virieu-le-Grand  1452                1  210104527  200040350
# 387      Arvière-en-Valromey  1453                1  200086403  200040350
# 388                 Virignin  1454                1  210104543  200040350
# 389                  Vongnes  1456                1  210104568  200040350
# 390                   Vonnas  1457                1  210104576  200070555
#
#      codeRegion codesPostaux  population
# 0            84      [01400]         859
# 1            84      [01640]         273
# 2            84      [01500]       15554
# 3            84      [01330]        1917
# 4            84      [01300]         114
# ..          ...          ...         ...
# 386          84      [01510]        1110
# 387          84      [01260]         715
# 388          84      [01300]        1122
# 389          84      [01350]          71
# 390          84      [01540]        3233
#
# [391 rows x 8 columns]

# %%
df.to_csv('Donnees\Liste_de_communes_par_départements.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\L'
# <>:1: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\pc\AppData\Local\Temp\ipykernel_28592\775841430.py:1: SyntaxWarning: invalid escape sequence '\L'
#   df.to_csv('Donnees\Liste_de_communes_par_départements.csv')

# %%
df.isna().sum()
# Out:
# nom                0
# code               0
# codeDepartement    0
# siren              0
# codeEpci           0
# codeRegion         0
# codesPostaux       0
# population         0
# dtype: int64

# %%
df['codeDepartement'].unique()
# Out:
# array([1], dtype=int64)

# %%
df['nom'].unique()
# Out:
# array(["L'Abergement-Clémenciat", "L'Abergement-de-Varey",
#        'Ambérieu-en-Bugey', 'Ambérieux-en-Dombes', 'Ambléon', 'Ambronay',
#        'Ambutrix', 'Andert-et-Condon', 'Anglefort', 'Apremont', 'Aranc',
#        'Arandas', 'Arbent', 'Arboys en Bugey', 'Arbigny', 'Argis',
#        'Armix', 'Ars-sur-Formans', 'Artemare', 'Asnières-sur-Saône',
#        'Attignat', 'Bâgé-Dommartin', 'Bâgé-le-Châtel', 'Balan', 'Baneins',
#        'Beaupont', 'Beauregard', 'Bellignat', 'Béligneux', 'Valserhône',
#        'Belley', 'Belleydoux', 'Valromey-sur-Séran', 'Bénonces', 'Bény',
#        'Béréziat', 'Bettant', 'Bey', 'Beynost', 'Billiat', 'Birieux',
#        'Biziat', 'Blyes', 'La Boisse', 'Boissey', 'Bolozon', 'Bouligneux',
#        'Bourg-en-Bresse', 'Bourg-Saint-Christophe', 'Boyeux-Saint-Jérôme',
#        'Boz', 'Brégnier-Cordon', 'Brénod', 'Brens', 'Bressolles', 'Brion',
#        'Briord', 'Buellas', 'La Burbanche', 'Ceignes', 'Cerdon',
#        'Certines', 'Cessy', 'Ceyzériat', 'Ceyzérieu', 'Chalamont',
#        'Chaleins', 'Chaley', 'Challes-la-Montagne', 'Challex',
#        'Champagne-en-Valromey', 'Champdor-Corcelles', 'Champfromier',
#        'Chanay', 'Chaneins', 'Chanoz-Châtenay',
#        'La Chapelle-du-Châtelard', 'Charix', 'Charnoz-sur-Ain',
#        'Château-Gaillard', 'Châtenay', 'Châtillon-la-Palud',
#        'Châtillon-sur-Chalaronne', 'Chavannes-sur-Reyssouze',
#        'Nivigne et Suran', 'Chaveyriat', 'Chazey-Bons', 'Chazey-sur-Ain',
#        'Cheignieu-la-Balme', 'Chevillard', 'Chevroux', 'Chevry',
#        'Chézery-Forens', 'Civrieux', 'Cize', 'Cleyzieu', 'Coligny',
#        'Collonges', 'Colomieu', 'Conand', 'Condamine', 'Condeissiat',
#        'Confort', 'Confrançon', 'Contrevoz', 'Conzieu', 'Corbonod',
#        'Corlier', 'Cormoranche-sur-Saône', 'Cormoz', 'Corveissiat',
#        'Courmangoux', 'Courtes', 'Crans', 'Bresse Vallons',
#        'Cressin-Rochefort', 'Crottet', 'Crozet', 'Cruzilles-lès-Mépillat',
#        'Culoz-Béon', 'Curciat-Dongalon', 'Curtafond', 'Cuzieu', 'Dagneux',
#        'Divonne-les-Bains', 'Dompierre-sur-Veyle',
#        'Dompierre-sur-Chalaronne', 'Domsure', 'Dortan', 'Douvres', 'Drom',
#        'Druillat', 'Échallon', 'Échenevex', 'Évosges', 'Faramans',
#        'Fareins', 'Farges', 'Feillens', 'Ferney-Voltaire', 'Flaxieu',
#        'Foissiat', 'Francheleins', 'Frans', 'Garnerans', 'Genouilleux',
#        'Béard-Géovreissiat', 'Géovreisset', 'Gex', 'Giron', 'Gorrevod',
#        'Grand-Corent', 'Grièges', 'Grilly', 'Groissiat', 'Guéreins',
#        'Hautecourt-Romanèche', "Plateau d'Hauteville", 'Haut Valromey',
#        'Illiat', 'Injoux-Génissiat', 'Innimond', 'Izenave', 'Izernore',
#        'Izieu', 'Jassans-Riottier', 'Jasseron', 'Jayat', 'Journans',
#        'Joyeux', 'Jujurieux', 'Labalme', 'Lagnieu', 'Laiz',
#        'Le Poizat-Lalleyriat', 'Lantenay', 'Lapeyrouse', 'Lavours',
#        'Léaz', 'Lélex', 'Lent', 'Lescheroux', 'Leyment', 'Leyssard',
#        'Surjoux-Lhopital', 'Lhuis', 'Lompnas', 'Loyettes', 'Lurcy',
#        'Magnieu', 'Maillat', 'Malafretaz', 'Mantenay-Montlin', 'Manziat',
#        'Marboz', 'Marchamp', 'Marignieu', 'Marlieux', 'Marsonnas',
#        'Martignat', 'Massieux', 'Massignieu-de-Rives',
#        'Matafelon-Granges', 'Meillonnas', 'Mérignat', 'Messimy-sur-Saône',
#        'Meximieux', 'Bohas-Meyriat-Rignat', 'Mézériat', 'Mijoux',
#        'Mionnay', 'Miribel', 'Misérieux', 'Mogneneins', 'Montagnat',
#        'Montagnieu', 'Montanges', 'Montceaux', 'Montcet', 'Le Montellier',
#        'Monthieux', 'Montluel', 'Montmerle-sur-Saône', 'Montracol',
#        'Montréal-la-Cluse', 'Montrevel-en-Bresse', 'Nurieux-Volognat',
#        'Murs-et-Gélignieux', 'Nantua', 'Neuville-les-Dames',
#        'Neuville-sur-Ain', 'Les Neyrolles', 'Neyron', 'Niévroz',
#        'Nivollet-Montgriffon', 'Oncieu', 'Ordonnaz', 'Ornex', 'Outriaz',
#        'Oyonnax', 'Ozan', 'Parcieux', 'Parves et Nattages', 'Péron',
#        'Péronnas', 'Pérouges', 'Perrex', 'Peyriat', 'Peyrieu',
#        'Peyzieux-sur-Saône', 'Pirajoux', 'Pizay', 'Plagne', 'Le Plantay',
#        'Polliat', 'Pollieu', 'Poncin', "Pont-d'Ain", 'Pont-de-Vaux',
#        'Pont-de-Veyle', 'Port', 'Pougny', 'Pouillat', 'Prémeyzel',
#        'Prémillieu', 'Prévessin-Moëns', 'Priay', 'Ramasse', 'Rancé',
#        'Relevant', 'Replonges', 'Revonnas', 'Reyrieux', 'Reyssouze',
#        'Rignieux-le-Franc', 'Romans', 'Rossillon', 'Saint-Alban',
#        'Saint-André-de-Bâgé', 'Saint-André-de-Corcy',
#        "Saint-André-d'Huiriat", 'Saint-André-le-Bouchoux',
#        'Saint-André-sur-Vieux-Jonc', 'Saint-Bénigne',
#        'Groslée-Saint-Benoit', 'Saint-Bernard', 'Sainte-Croix',
#        'Saint-Cyr-sur-Menthon', 'Saint-Denis-lès-Bourg',
#        'Saint-Denis-en-Bugey', "Saint-Didier-d'Aussiat",
#        'Saint-Didier-de-Formans', 'Saint-Didier-sur-Chalaronne',
#        'Saint-Éloi', 'Saint-Étienne-du-Bois',
#        'Saint-Étienne-sur-Chalaronne', 'Saint-Étienne-sur-Reyssouze',
#        'Sainte-Euphémie', 'Saint-Genis-Pouilly',
#        'Saint-Genis-sur-Menthon', 'Saint-Georges-sur-Renon',
#        'Saint-Germain-de-Joux', 'Saint-Germain-les-Paroisses',
#        'Saint-Germain-sur-Renon', 'Saint-Jean-de-Gonville',
#        'Saint-Jean-de-Niost', 'Saint-Jean-de-Thurigneux',
#        'Saint-Jean-le-Vieux', 'Saint-Jean-sur-Reyssouze',
#        'Saint-Jean-sur-Veyle', 'Sainte-Julie',
#        'Saint-Julien-sur-Reyssouze', 'Saint-Julien-sur-Veyle',
#        'Saint-Just', 'Saint-Laurent-sur-Saône', 'Saint-Marcel',
#        'Saint-Martin-de-Bavel', 'Saint-Martin-du-Frêne',
#        'Saint-Martin-du-Mont', 'Saint-Martin-le-Châtel',
#        'Saint-Maurice-de-Beynost', 'Saint-Maurice-de-Gourdans',
#        'Saint-Maurice-de-Rémens', 'Saint-Nizier-le-Bouchoux',
#        'Saint-Nizier-le-Désert', 'Sainte-Olive', 'Saint-Paul-de-Varax',
#        'Saint-Rambert-en-Bugey', 'Saint-Rémy', 'Saint-Sorlin-en-Bugey',
#        'Saint-Sulpice', 'Saint-Trivier-de-Courtes',
#        'Saint-Trivier-sur-Moignans', 'Saint-Vulbas', 'Salavre',
#        'Samognat', 'Sandrans', 'Sault-Brénaz', 'Sauverny', 'Savigneux',
#        'Ségny', 'Seillonnaz', 'Sergy', 'Sermoyer', 'Serrières-de-Briord',
#        'Serrières-sur-Ain', 'Servas', 'Servignat', 'Seyssel',
#        'Simandre-sur-Suran', 'Sonthonnax-la-Montagne', 'Souclin',
#        'Sulignat', 'Talissieu', 'Tenay', 'Thil', 'Thoiry', 'Thoissey',
#        'Torcieu', 'Tossiat', 'Toussieux', 'Tramoyes', 'La Tranclière',
#        'Val-Revermont', 'Trévoux', 'Valeins', 'Vandeins', 'Varambon',
#        'Vaux-en-Bugey', 'Verjon', 'Vernoux', 'Versailleux', 'Versonnex',
#        'Vesancy', 'Vescours', 'Vésines', "Vieu-d'Izenave",
#        'Villars-les-Dombes', 'Villebois', 'Villemotier', 'Villeneuve',
#        'Villereversure', 'Villes', 'Villette-sur-Ain',
#        'Villieu-Loyes-Mollon', 'Viriat', 'Virieu-le-Grand',
#        'Arvière-en-Valromey', 'Virignin', 'Vongnes', 'Vonnas'],
#       dtype=object)

# %%
df.loc[df['codeDepartement'].astype(str).str.contains("uvergne", na=False)]
# Out:
# Empty DataFrame
# Columns: [nom, code, codeDepartement, siren, codeEpci, codeRegion, codesPostaux, population]
# Index: []

# %%
import requests
import csv
import time

# --- 1. Récupération de tous les départements ---
url_departements = "https://geo.api.gouv.fr/departements"
departements = requests.get(url_departements).json()

print(f"{len(departements)} départements trouvés.")

# --- 2. Préparer le fichier CSV ---
fichier_csv = "communes_france.csv"

# Définir les en-têtes du fichier
entetes = ["code_commune", "nom_commune", "code_departement", "nom_departement"]

with open(fichier_csv, "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(entetes)

    # --- 3. Boucler sur chaque département ---
    for dep in departements:
        code_dep = dep["code"]
        nom_dep = dep["nom"]
        print(f"→ Récupération des communes du département {nom_dep} ({code_dep})")

        url_communes = f"https://geo.api.gouv.fr/departements/{code_dep}/communes"
        communes = requests.get(url_communes).json()

        # --- 4. Écrire chaque commune dans le CSV ---
        for c in communes:
            writer.writerow([c["code"], c["nom"], code_dep, nom_dep])

        # Petite pause pour ne pas surcharger le serveur
        time.sleep(0.3)

print(f"✅ Fichier '{fichier_csv}' créé avec succès !")
# Out:
# 101 départements trouvés.
# → Récupération des communes du département Ain (01)
# → Récupération des communes du département Aisne (02)
# → Récupération des communes du département Allier (03)
# → Récupération des communes du département Alpes-de-Haute-Provence (04)
# → Récupération des communes du département Hautes-Alpes (05)
# → Récupération des communes du département Alpes-Maritimes (06)
# → Récupération des communes du département Ardèche (07)
# → Récupération des communes du département Ardennes (08)
# → Récupération des communes du département Ariège (09)
# → Récupération des communes du département Aube (10)
# → Récupération des communes du département Aude (11)
# → Récupération des communes du département Aveyron (12)
# → Récupération des communes du département Bouches-du-Rhône (13)
# → Récupération des communes du département Calvados (14)
# → Récupération des communes du département Cantal (15)
# → Récupération des communes du département Charente (16)
# → Récupération des communes du département Charente-Maritime (17)
# → Récupération des communes du département Cher (18)
# → Récupération des communes du département Corrèze (19)
# → Récupération des communes du département Côte-d'Or (21)
# → Récupération des communes du département Côtes-d'Armor (22)
# → Récupération des communes du département Creuse (23)
# → Récupération des communes du département Dordogne (24)
# → Récupération des communes du département Doubs (25)
# → Récupération des communes du département Drôme (26)
# → Récupération des communes du département Eure (27)
# → Récupération des communes du département Eure-et-Loir (28)
# → Récupération des communes du département Finistère (29)
# → Récupération des communes du département Corse-du-Sud (2A)
# → Récupération des communes du département Haute-Corse (2B)
# → Récupération des communes du département Gard (30)
# → Récupération des communes du département Haute-Garonne (31)
# → Récupération des communes du département Gers (32)
# → Récupération des communes du département Gironde (33)
# → Récupération des communes du département Hérault (34)
# → Récupération des communes du département Ille-et-Vilaine (35)
# → Récupération des communes du département Indre (36)
# → Récupération des communes du département Indre-et-Loire (37)
# → Récupération des communes du département Isère (38)
# → Récupération des communes du département Jura (39)
# → Récupération des communes du département Landes (40)
# → Récupération des communes du département Loir-et-Cher (41)
# → Récupération des communes du département Loire (42)
# → Récupération des communes du département Haute-Loire (43)
# → Récupération des communes du département Loire-Atlantique (44)
# → Récupération des communes du département Loiret (45)
# → Récupération des communes du département Lot (46)
# → Récupération des communes du département Lot-et-Garonne (47)
# → Récupération des communes du département Lozère (48)
# → Récupération des communes du département Maine-et-Loire (49)
# → Récupération des communes du département Manche (50)
# → Récupération des communes du département Marne (51)
# → Récupération des communes du département Haute-Marne (52)
# → Récupération des communes du département Mayenne (53)
# → Récupération des communes du département Meurthe-et-Moselle (54)
# → Récupération des communes du département Meuse (55)
# → Récupération des communes du département Morbihan (56)
# → Récupération des communes du département Moselle (57)
# → Récupération des communes du département Nièvre (58)
# → Récupération des communes du département Nord (59)
# → Récupération des communes du département Oise (60)
# → Récupération des communes du département Orne (61)
# → Récupération des communes du département Pas-de-Calais (62)
# → Récupération des communes du département Puy-de-Dôme (63)
# → Récupération des communes du département Pyrénées-Atlantiques (64)
# → Récupération des communes du département Hautes-Pyrénées (65)
# → Récupération des communes du département Pyrénées-Orientales (66)
# → Récupération des communes du département Bas-Rhin (67)
# → Récupération des communes du département Haut-Rhin (68)
# → Récupération des communes du département Rhône (69)
# → Récupération des communes du département Haute-Saône (70)
# → Récupération des communes du département Saône-et-Loire (71)
# → Récupération des communes du département Sarthe (72)
# → Récupération des communes du département Savoie (73)
# → Récupération des communes du département Haute-Savoie (74)
# → Récupération des communes du département Paris (75)
# → Récupération des communes du département Seine-Maritime (76)
# → Récupération des communes du département Seine-et-Marne (77)
# → Récupération des communes du département Yvelines (78)
# → Récupération des communes du département Deux-Sèvres (79)
# → Récupération des communes du département Somme (80)
# → Récupération des communes du département Tarn (81)
# → Récupération des communes du département Tarn-et-Garonne (82)
# → Récupération des communes du département Var (83)
# → Récupération des communes du département Vaucluse (84)
# → Récupération des communes du département Vendée (85)
# → Récupération des communes du département Vienne (86)
# → Récupération des communes du département Haute-Vienne (87)
# → Récupération des communes du département Vosges (88)
# → Récupération des communes du département Yonne (89)
# → Récupération des communes du département Territoire de Belfort (90)
# → Récupération des communes du département Essonne (91)
# → Récupération des communes du département Hauts-de-Seine (92)
# → Récupération des communes du département Seine-Saint-Denis (93)
# → Récupération des communes du département Val-de-Marne (94)
# → Récupération des communes du département Val-d'Oise (95)
# → Récupération des communes du département Guadeloupe (971)
# → Récupération des communes du département Martinique (972)
# → Récupération des communes du département Guyane (973)
# → Récupération des communes du département La Réunion (974)
# → Récupération des communes du département Mayotte (976)
# ✅ Fichier 'communes_france.csv' créé avec succès !

# %%
import requests
url_departements = "https://geo.api.gouv.fr/departements"
departements = requests.get(url_departements).json()

print(f"{len(departements)} départements trouvés.")
# Out:
# 101 départements trouvés.

# %%
departements[0]
# Out:
# {'nom': 'Ain', 'code': '01', 'codeRegion': '84'}

# %%
for i , dept  in enumerate(departements):
    if 'nom' in dept and 'paris' in dept['nom'].lower():
        print("Arrêt : j'ai trouvé en indice ",i)
        break
# Out:
# Arrêt : j'ai trouvé en indice  75

# %%
import pandas as pd
df=pd.read_csv('Donnees/communes_france.csv')

# %%
df.head()
# Out:
#   code_commune              nom_commune code_departement nom_departement
# 0        01001  L'Abergement-Clémenciat               01             Ain
# 1        01002    L'Abergement-de-Varey               01             Ain
# 2        01004        Ambérieu-en-Bugey               01             Ain
# 3        01005      Ambérieux-en-Dombes               01             Ain
# 4        01006                  Ambléon               01             Ain

# %%
df['nom_departement'].unique().size
# Out:
# 101

# %%
import requests

url = 'https://geo.api.gouv.fr/regions'
# A GET request to the API
response = requests.get(url)
# Print the response
data_region = response.json()
print(data_region[0])
# Out:
# {'nom': 'Île-de-France', 'code': '11'}
