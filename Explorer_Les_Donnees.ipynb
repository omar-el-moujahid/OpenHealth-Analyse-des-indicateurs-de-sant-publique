# %%
import requests
import csv
import time

# --- 1. Récupération de tous les départements ---
url_departements = "https://geo.api.gouv.fr/departements"
departements = requests.get(url_departements).json()

print(f"{len(departements)} départements trouvés.")

# --- 2. Préparer le fichier CSV ---
fichier_csv = "communes_france.csv"

# Définir les en-têtes du fichier
entetes = ["code_commune", "nom_commune", "code_departement", "nom_departement"]

with open(fichier_csv, "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(entetes)

    # --- 3. Boucler sur chaque département ---
    for dep in departements:
        code_dep = dep["code"]
        nom_dep = dep["nom"]
        print(f"→ Récupération des communes du département {nom_dep} ({code_dep})")

        url_communes = f"https://geo.api.gouv.fr/departements/{code_dep}/communes"
        communes = requests.get(url_communes).json()

        # --- 4. Écrire chaque commune dans le CSV ---
        for c in communes:
            writer.writerow([c["code"], c["nom"], code_dep, nom_dep])

        # Petite pause pour ne pas surcharger le serveur
        time.sleep(0.3)

print(f"✅ Fichier '{fichier_csv}' créé avec succès !")
# Out:
# 101 départements trouvés.
# → Récupération des communes du département Ain (01)
# → Récupération des communes du département Aisne (02)
# → Récupération des communes du département Allier (03)
# → Récupération des communes du département Alpes-de-Haute-Provence (04)
# → Récupération des communes du département Hautes-Alpes (05)
# → Récupération des communes du département Alpes-Maritimes (06)
# → Récupération des communes du département Ardèche (07)
# → Récupération des communes du département Ardennes (08)
# → Récupération des communes du département Ariège (09)
# → Récupération des communes du département Aube (10)
# → Récupération des communes du département Aude (11)
# → Récupération des communes du département Aveyron (12)
# → Récupération des communes du département Bouches-du-Rhône (13)
# → Récupération des communes du département Calvados (14)
# → Récupération des communes du département Cantal (15)
# → Récupération des communes du département Charente (16)
# → Récupération des communes du département Charente-Maritime (17)
# → Récupération des communes du département Cher (18)
# → Récupération des communes du département Corrèze (19)
# → Récupération des communes du département Côte-d'Or (21)
# → Récupération des communes du département Côtes-d'Armor (22)
# → Récupération des communes du département Creuse (23)
# → Récupération des communes du département Dordogne (24)
# → Récupération des communes du département Doubs (25)
# → Récupération des communes du département Drôme (26)
# → Récupération des communes du département Eure (27)
# → Récupération des communes du département Eure-et-Loir (28)
# → Récupération des communes du département Finistère (29)
# → Récupération des communes du département Corse-du-Sud (2A)
# → Récupération des communes du département Haute-Corse (2B)
# → Récupération des communes du département Gard (30)
# → Récupération des communes du département Haute-Garonne (31)
# → Récupération des communes du département Gers (32)
# → Récupération des communes du département Gironde (33)
# → Récupération des communes du département Hérault (34)
# → Récupération des communes du département Ille-et-Vilaine (35)
# → Récupération des communes du département Indre (36)
# → Récupération des communes du département Indre-et-Loire (37)
# → Récupération des communes du département Isère (38)
# → Récupération des communes du département Jura (39)
# → Récupération des communes du département Landes (40)
# → Récupération des communes du département Loir-et-Cher (41)
# → Récupération des communes du département Loire (42)
# → Récupération des communes du département Haute-Loire (43)
# → Récupération des communes du département Loire-Atlantique (44)
# → Récupération des communes du département Loiret (45)
# → Récupération des communes du département Lot (46)
# → Récupération des communes du département Lot-et-Garonne (47)
# → Récupération des communes du département Lozère (48)
# → Récupération des communes du département Maine-et-Loire (49)
# → Récupération des communes du département Manche (50)
# → Récupération des communes du département Marne (51)
# → Récupération des communes du département Haute-Marne (52)
# → Récupération des communes du département Mayenne (53)
# → Récupération des communes du département Meurthe-et-Moselle (54)
# → Récupération des communes du département Meuse (55)
# → Récupération des communes du département Morbihan (56)
# → Récupération des communes du département Moselle (57)
# → Récupération des communes du département Nièvre (58)
# → Récupération des communes du département Nord (59)
# → Récupération des communes du département Oise (60)
# → Récupération des communes du département Orne (61)
# → Récupération des communes du département Pas-de-Calais (62)
# → Récupération des communes du département Puy-de-Dôme (63)
# → Récupération des communes du département Pyrénées-Atlantiques (64)
# → Récupération des communes du département Hautes-Pyrénées (65)
# → Récupération des communes du département Pyrénées-Orientales (66)
# → Récupération des communes du département Bas-Rhin (67)
# → Récupération des communes du département Haut-Rhin (68)
# → Récupération des communes du département Rhône (69)
# → Récupération des communes du département Haute-Saône (70)
# → Récupération des communes du département Saône-et-Loire (71)
# → Récupération des communes du département Sarthe (72)
# → Récupération des communes du département Savoie (73)
# → Récupération des communes du département Haute-Savoie (74)
# → Récupération des communes du département Paris (75)
# → Récupération des communes du département Seine-Maritime (76)
# → Récupération des communes du département Seine-et-Marne (77)
# → Récupération des communes du département Yvelines (78)
# → Récupération des communes du département Deux-Sèvres (79)
# → Récupération des communes du département Somme (80)
# → Récupération des communes du département Tarn (81)
# → Récupération des communes du département Tarn-et-Garonne (82)
# → Récupération des communes du département Var (83)
# → Récupération des communes du département Vaucluse (84)
# → Récupération des communes du département Vendée (85)
# → Récupération des communes du département Vienne (86)
# → Récupération des communes du département Haute-Vienne (87)
# → Récupération des communes du département Vosges (88)
# → Récupération des communes du département Yonne (89)
# → Récupération des communes du département Territoire de Belfort (90)
# → Récupération des communes du département Essonne (91)
# → Récupération des communes du département Hauts-de-Seine (92)
# → Récupération des communes du département Seine-Saint-Denis (93)
# → Récupération des communes du département Val-de-Marne (94)
# → Récupération des communes du département Val-d'Oise (95)
# → Récupération des communes du département Guadeloupe (971)
# → Récupération des communes du département Martinique (972)
# → Récupération des communes du département Guyane (973)
# → Récupération des communes du département La Réunion (974)
# → Récupération des communes du département Mayotte (976)
# ✅ Fichier 'communes_france.csv' créé avec succès !

# %%
import requests
url_departements = "https://geo.api.gouv.fr/departements"
departements = requests.get(url_departements).json()

print(f"{len(departements)} départements trouvés.")
# Out:
# 101 départements trouvés.

# %%
# Out:
# {'nom': 'Ain', 'code': '01', 'codeRegion': '84'}

# %%
departements[0]
# Out:
# {'nom': 'Ain', 'code': '01', 'codeRegion': '84'}

# %%
import csv
col = ["nom", "code", "codeRegion"]
fichier_csv='Donnees/departement_france.csv'
with open(fichier_csv, "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(col)

    for dep in departements:
        writer.writerow([dep['nom'],dep['code'],dep['codeRegion']])

# %%
for i , dept  in enumerate(departements):
    if 'nom' in dept and 'paris' in dept['nom'].lower():
        print("Arrêt : j'ai trouvé en indice ",i)
        break
# Out:
# Arrêt : j'ai trouvé en indice  75

# %%
import pandas as pd
df=pd.read_csv('Donnees/communes_france.csv')

# %%
df.head()
# Out:
#   code_commune              nom_commune code_departement nom_departement
# 0        01001  L'Abergement-Clémenciat               01             Ain
# 1        01002    L'Abergement-de-Varey               01             Ain
# 2        01004        Ambérieu-en-Bugey               01             Ain
# 3        01005      Ambérieux-en-Dombes               01             Ain
# 4        01006                  Ambléon               01             Ain

# %%
df['nom_departement'].unique().size
# Out:
# 101

# %%
import requests

url = 'https://geo.api.gouv.fr/regions'
# A GET request to the API
response = requests.get(url)
# Print the response
data_region = response.json()
print(data_region[0])
# Out:
# {'nom': 'Île-de-France', 'code': '11'}

# %%
print(len(data_region))
# Out:
# 18

# %%
import csv
col = ["nom", "code"]
fichier_csv='Donnees/region_france.csv'
with open(fichier_csv, "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(col)

    for dep in departements:
        writer.writerow([dep['nom'],dep['code']])

# %%
import pandas as pd

df = pd.read_csv(
    'Donnees/sante/pathologie_effectifs_en_fnct_des_régions.csv', 
    sep=';',  
    engine='python' 
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5216400 entries, 0 to 5216399
# Data columns (total 16 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   annee               int64
#  1   patho_niv1          object
#  2   patho_niv2          object
#  3   patho_niv3          object
#  4   top                 object
#  5   cla_age_5           object
#  6   sexe                int64
#  7   region              int64
#  8   dept                object
#  9   Ntop                float64
#  10  Npop                int64
#  11  prev                float64
#  12  Niveau prioritaire  object
#  13  libelle_classe_age  object
#  14  libelle_sexe        object
#  15  tri                 float64
# dtypes: float64(3), int64(4), object(9)
# memory usage: 636.8+ MB

# %%
df['patho_niv1'].unique()
# Out:
# array(['Maladies inflammatoires ou rares ou infection VIH',
#        'Maladies neurologiques', 'Maladies psychiatriques',
#        'Pas de pathologie repérée, traitement, maternité, hospitalisation ou traitement antalgique ou anti-inflammatoire',
#        'Total consommants tous régimes',
#        'Traitements du risque vasculaire (hors pathologies)',
#        'Traitements psychotropes (hors pathologies)',
#        'Maladies cardioneurovasculaires',
#        'Maladies respiratoires chroniques (hors mucoviscidose)',
#        'Traitements antalgiques ou anti-inflammatoires (hors pathologies, traitements, maternité ou hospitalisations)',
#        'Maladies du foie ou du pancréas (hors mucoviscidose)',
#        'Maternité (avec ou sans pathologies)',
#        'Insuffisance rénale chronique terminale',
#        'Hospitalisations hors pathologies repérées (avec ou sans pathologies, traitements ou maternité)',
#        'Cancers', 'Diabète', 'Hospitalisation pour Covid-19',
#        "Affections de longue durée (dont 31 et 32) pour d'autres causes"],
#       dtype=object)

# %%
df['patho_niv2'].unique()
# Out:
# array(['Maladies rares', nan, 'Autres affections neurologiques',
#        'Autres troubles psychiatriques', 'Déficience mentale',
#        'Pas de pathologie repérée, traitement, maternité, hospitalisation ou traitement antalgique ou anti-inflammatoire',
#        'Total consommants tous régimes',
#        'Traitements antihypertenseurs (hors pathologies)',
#        'Traitements antidépresseurs ou thymorégulateurs (hors pathologies)',
#        'Traitements anxiolytiques (hors pathologies)',
#        'Infection par le VIH',
#        'Traitements hypolipémiants (hors pathologies)',
#        'Troubles addictifs', "Troubles névrotiques et de l'humeur",
#        "Troubles psychiatriques débutant dans l'enfance",
#        'Troubles psychotiques', 'Maladies inflammatoires chroniques',
#        'Maladie coronaire', 'Maladie valvulaire',
#        'Insuffisance cardiaque', 'Artériopathie périphérique',
#        'Autres affections cardiovasculaires',
#        "Démences (dont maladie d'Alzheimer)", 'Lésion médullaire',
#        'Sclérose en plaques', 'Épilepsie', 'Maladie de Parkinson',
#        'Myopathie ou myasthénie', 'Embolie pulmonaire',
#        'Maladies respiratoires chroniques (hors mucoviscidose)',
#        'Traitements antalgiques ou anti-inflammatoires (hors pathologies, traitements, maternité ou hospitalisations)',
#        'Maladies du foie ou du pancréas (hors mucoviscidose)',
#        'Maternité (avec ou sans pathologies)',
#        'Traitements hypnotiques (hors pathologies)',
#        'Traitements neuroleptiques (hors pathologies)',
#        'Accident vasculaire cérébral', 'Transplantation rénale',
#        'Hospitalisations hors pathologies repérées (avec ou sans pathologies, traitements ou maternité)',
#        'Cancer du sein de la femme', 'Diabète', 'Cancer de la prostate',
#        'Cancer colorectal', 'Dialyse chronique',
#        'Suivi de transplantation rénale', 'Hospitalisation pour Covid-19',
#        "Affections de longue durée (dont 31 et 32) pour d'autres causes",
#        'Autres cancers',
#        'Troubles du rythme ou de la conduction cardiaque',
#        'Cancer bronchopulmonaire'], dtype=object)

# %%
df.head(20)
# Out:
#     annee                                         patho_niv1      patho_niv2  \
# 0    2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 1    2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 2    2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 3    2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 4    2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 5    2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 6    2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 7    2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 8    2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 9    2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 10   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 11   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 12   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 13   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 14   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 15   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 16   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 17   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 18   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 19   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
#
#        patho_niv3          top cla_age_5  sexe  region dept  Ntop   Npop  \
# 0   Mucoviscidose  RAR_MUC_IND     95et+     9      28  999   NaN  15550
# 1   Mucoviscidose  RAR_MUC_IND     95et+     9      32   59   NaN   8460
# 2   Mucoviscidose  RAR_MUC_IND     95et+     9      32   60   NaN   2470
# 3   Mucoviscidose  RAR_MUC_IND     95et+     9      32   62   NaN   5010
# 4   Mucoviscidose  RAR_MUC_IND     95et+     9      32   80   NaN   2220
# 5   Mucoviscidose  RAR_MUC_IND     95et+     9      32  999   NaN  20270
# 6   Mucoviscidose  RAR_MUC_IND     95et+     9      44   10   NaN   1570
# 7   Mucoviscidose  RAR_MUC_IND     95et+     9      44   51   NaN   2190
# 8   Mucoviscidose  RAR_MUC_IND     95et+     9      44   55   NaN    850
# 9   Mucoviscidose  RAR_MUC_IND     95et+     9      44   67   NaN   3990
# 10  Mucoviscidose  RAR_MUC_IND     95et+     9      44   68   NaN   2650
# 11  Mucoviscidose  RAR_MUC_IND     95et+     9      53   29   NaN   4370
# 12  Mucoviscidose  RAR_MUC_IND     95et+     9      53   56   NaN   3940
# 13  Mucoviscidose  RAR_MUC_IND     95et+     9      75   16   NaN   2200
# 14  Mucoviscidose  RAR_MUC_IND     95et+     9      75   17   NaN   4500
# 15  Mucoviscidose  RAR_MUC_IND     95et+     9      75   19   NaN   1740
# 16  Mucoviscidose  RAR_MUC_IND     95et+     9      75   23   NaN    980
# 17  Mucoviscidose  RAR_MUC_IND     95et+     9      75   64   NaN   4460
# 18  Mucoviscidose  RAR_MUC_IND     95et+     9      75  999   NaN  37250
# 19  Mucoviscidose  RAR_MUC_IND     95et+     9      76   12   NaN   1950
#
#     prev Niveau prioritaire libelle_classe_age libelle_sexe   tri
# 0    NaN                  3     plus de 95 ans   tous sexes  78.0
# 1    NaN                  3     plus de 95 ans   tous sexes  78.0
# 2    NaN                  3     plus de 95 ans   tous sexes  78.0
# 3    NaN                  3     plus de 95 ans   tous sexes  78.0
# 4    NaN                  3     plus de 95 ans   tous sexes  78.0
# 5    NaN                  3     plus de 95 ans   tous sexes  78.0
# 6    NaN                  3     plus de 95 ans   tous sexes  78.0
# 7    NaN                  3     plus de 95 ans   tous sexes  78.0
# 8    NaN                  3     plus de 95 ans   tous sexes  78.0
# 9    NaN                  3     plus de 95 ans   tous sexes  78.0
# 10   NaN                  3     plus de 95 ans   tous sexes  78.0
# 11   NaN                  3     plus de 95 ans   tous sexes  78.0
# 12   NaN                  3     plus de 95 ans   tous sexes  78.0
# 13   NaN                  3     plus de 95 ans   tous sexes  78.0
# 14   NaN                  3     plus de 95 ans   tous sexes  78.0
# 15   NaN                  3     plus de 95 ans   tous sexes  78.0
# 16   NaN                  3     plus de 95 ans   tous sexes  78.0
# 17   NaN                  3     plus de 95 ans   tous sexes  78.0
# 18   NaN                  3     plus de 95 ans   tous sexes  78.0
# 19   NaN                  3     plus de 95 ans   tous sexes  78.0

# %%
df.isna().sum()
# Out:
# annee                       0
# patho_niv1                  0
# patho_niv2             544320
# patho_niv3            1179360
# top                         0
# cla_age_5                   0
# sexe                        0
# region                      0
# dept                        0
# Ntop                  1382435
# Npop                        0
# prev                  1382435
# Niveau prioritaire      68040
# libelle_classe_age          0
# libelle_sexe                0
# tri                     68040
# dtype: int64

# %%
df=df.dropna()

# %%
df.isna().sum()
# Out:
# annee                 0
# patho_niv1            0
# patho_niv2            0
# patho_niv3            0
# top                   0
# cla_age_5             0
# sexe                  0
# region                0
# dept                  0
# Ntop                  0
# Npop                  0
# prev                  0
# Niveau prioritaire    0
# libelle_classe_age    0
# libelle_sexe          0
# tri                   0
# dtype: int64

# %%
df.size
# Out:
# 44554960

# %%
df.groupby(['patho_niv1','sexe']).sum()

# %%
df.isna()

# %%
import csv 
fichier_csv='Donnees\sante\pathologie_effectifs_en_fnct_des_régions.csv'
with open(fichier_csv, "r", encoding="utf-8") as f:
    print(f)
# Out:
# <_io.TextIOWrapper name='Donnees\\sante\\pathologie_effectifs_en_fnct_des_régions.csv' mode='r' encoding='utf-8'>
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\pc\AppData\Local\Temp\ipykernel_9704\2328345764.py:2: SyntaxWarning: invalid escape sequence '\s'
#   fichier_csv='Donnees\sante\pathologie_effectifs_en_fnct_des_régions.csv'
